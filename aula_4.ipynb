# %% [markdown]
# <a href="https://colab.research.google.com/github/thialescalcante/arquivos_aula_linguagemPrograma-ao1/blob/main/aula_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Conteúdo do dia
#
# ##  Função
#
# * A estrutura interna (processamento) do programa basicamente não muda entre linguagens: na devastadora maioria, você terá, com algumas variações: a programação sequencial, as estruturas de controle (com desvios condicionais e laços de repetição), vetores/ matrizes, funções.
#
# * Python é muito utilizado para entender a "linguagem natural" (texto/ string) muito utilizado pra IA.
#
# ** Funções
# Exemplo: uma calculadora, mas que calcule equação da reta (y = ax + b).
# Para isso, precisaria pelo menos de um x1 que geraria y1 , e um x2 que geraria y2. Mas escrever etapa por etapa é meio paia, seria melhor ter algo que pode repetir isso pra mim. Isso que é a FUNÇÃO.
#
# Ou seja: dentro do seu programa vc constrói a lógica principal, e as atividades que são repetidas várias vezes vc coloca em "blocs externos" (tudo aquilo que vai se repetir no seu programa). A ideia é que elas não necessitem de uma estrutura linear, pois podem ser chamadas em diversas etapas do programa.
#
# Este conceito é chamado de MODULARIZAÇÃO. Sempre que você for usar esse módulo, precisa "chamar" ele. {o módulo pode estar dentro do programa ou fora dele}
#
# No nosso exemplo, quando a pessoa inserisse o valor de x1, ele puxaria o módulo para saber y1. Sozinho, pediria o x2, que voltaria para o módulo que calcula y2. Depois, seguiria o script. ISSO SÃO AS "FUNÇÕES".
#
#   Sintaxe:
#
# def<nomedafunção>(parametro):
#   instruções da função
# inst fora da função
#
# * o "parametro" são as entradas de função. Tudo que for usar para o módulo e estiver dentro dele, está em <nomedafuncao>
#
# * Exemplos de funções internas do python: input, print...
#
# *{Variáveis locais(dentro do módulo) x Variáveis globais(referentes ao código todo). Ao criar funções, é melhor que os parâmetros sejam variáveis LOCAIS pra deixar as variáveis globais em paz. É bom que os nomes das variáveis nos módulos sejam diferentes até entre as funções, pra não dar ruim.}*
#
# * Nas funções, para regar um resultado a ser utilizado no programa, precisa ter o RETURN. Assim, ela te "retorna" um valor para o código. Se usar por exemplo um PRINT no lugar do return, a função não guarda o valor, apesar dele existir.
#
#
# VOLTANDO AO EXEMPLO:
# Criar nossa função para uma equação da reta fica
# *{eval: pra quando não sabe se é float ou int, mas sabe que é número}*
#
#   Por ex: y = 7x + 8
#
# def reta(x):
#    return (7 * x + 8)
#
# ##  Versionamento
#
# A gente não faz alterações no código original, e sim hubificações/ ramificações {pra não prejudicar o que já funciona.
# Isso permite fazer um trabalho colaborativo, com cada pessoa cuidando de coisas diferentes, e o prório versionamento tem a etapa de unir tudo depois.
#
# * Git/ Github
# Github = armazena e faz hospedagem {repositório remoto}
# Git = o que tem na sua máquina para levar os arquivos ao Github {repositório local}

# %% [markdown]
# ## Exemplo 1

# %%
def reta(numero):
  return (7 * numero + 8)

def imprimir(num1, num2):
  print(f"O primeiro ponto da reta é {num1} e {num2}.")

x1 = int(input("Insira o primeiro valor de x: "))
y1 = reta(x1)

x2 = eval(input("Isira o segundo valor de x: "))
y2 = reta(x2)

print(imprimir(x1, y1))
print(imprimir(x2, y2))

#print(f"o primeiro ponto é {x1} e {y1}.")
#print(f"o segundo ponto é {x2} e {y2}.")

#Deu vários erros pra rodar no navegador, mas o código está certo e rodou no VSCODE.
# Out:
# Insira o primeiro valor de x: 4
# Isira o segundo valor de x: 9
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-5223f75922be> in <cell line: 0>()
#      11 y2 = reta(x2)
#      12
# ---> 13 print(imprimir(x1, y1))
#      14 print(imprimir(x2, y2))
#      15
#
# <ipython-input-20-5223f75922be> in imprimir(num1, num2)
#       3
#       4 def imprimir(num1, num2):
# ----> 5   print(f"O primeiro ponto da reta é {num1} e {num2}.")
#       6
#       7 x1 = int(input("Insira o primeiro valor de x: "))
#
# TypeError: 'str' object is not callable

# %% [markdown]
# ### Novidades neste exercício

# %% [markdown]
# ### Erros que cometi neste exercício

# %% [markdown]
# ## EXERCÍCIO 21 - Parâmetros, Descompactação e Vriáveis
#
# Testar no vscode ou outra IDE porque pelo navegador não deve funcionar. É necessário poder escrever no Terminal.
#
#  ![teste1.jpg](data:image/jpeg;base64,...)

# %%
from sys import argv #importa biblioteca
script, first, second, third = argv #precisa ser: nome do programa + variáveis

print("The script is called:", script) #imprime
print("Your fisrt variable is:", first) #imprime
print("Your second variable is:", second) #imprime
print("Your third variable is:", third) #imprime
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-99aea9830f76> in <cell line: 0>()
#       1 from sys import argv #importa biblioteca
# ----> 2 script, first, second, third = argv
#       3
#       4 print("The script is called:", script)
#       5 print("Your fisrt variable is:", first)
#
# ValueError: not enough values to unpack (expected 4, got 3)

# %% [markdown]
# ### Novidades neste exercício
#
# Importou a biblioteca argv, mas teve que escrever os valores no terminal pra rodar.

# %% [markdown]
# ### Erros que cometi neste exercício
#
# Erro na linha 2:
# ValueError: not enough values to unpack (expected 4, got 3). Indica que não tem argumentos suficientes pra rodar o código.

# %% [markdown]
# ## EXERCÍCIO 22 - Parâmetros, Descompactação e Variáveis
#
# Ele não vai conseguir rodar no navegador porque precisa de Terminal.
#
# ![{7DA16AF4-E45F-45B9-8AB5-8D0FE43D5294}.png](data:image/png;base64,...)

# %%
from sys import argv

script, user_name = argv
prompt = '> '

print(f"Hi {user_name}, I'm the {script} script.")
print("I'd like to ask you a few questions.")
print(f"Do you like me {user_name}?")
likes = input(prompt)

print(f"Where do you live {user_name}?")
lives = input(prompt)

print("What kind of computer do you have?")
computer = input(prompt)

print(f"""
Alright, so you said {likes} about liking me.
You live in {lives}. Not sure where that is.
And you have a {computer} computer. Nice.
""")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-22-1d93e0050087> in <cell line: 0>()
# ----> 1 from sus import argv
#       2
#       3 script, user_name = argv
#       4 prompt = '> '
#       5
#
# ModuleNotFoundError: No module named 'sus'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# ### Novidades neste exercício
#
# Para rodar no terminal, foi necessário:
# * Copiei o código no VSCode, salvei no mesmo diretório
# * No terminal, digitei "python teste.py Laix" -> sendo "Laix" o user_name.

# %% [markdown]
# ### Erros que cometi neste exercício
#
# Somente digitação que a biblioteca sus não existe, só a sys mesmo

# %% [markdown]
# ## EXERCÍCIO 16 - Loops e listas

# %%
the_count = [1, 2, 3, 4, 5] #cria lista the_count
fruits = ['apples', 'oranges', 'pears', 'apricots'] #cria lista fruits
change = [1, 'pennies', 2, 'dimes', 3, 'quarters'] #cria lista change

for number in the_count: #para cada elemento dentro de the_count, que chamei de number, ele:
  print(f"This is count {number}") #imprime cada elemento

for fruit in fruits: #para cada elemento dentro de fruits, que chamei de fruit, ele:
  print(f"A fruit of type: {fruit}") #imprime cada elemento

for i in change: #para cada elemento dentro de change, identificado pelo padrão i, ele:
  print(f"I got {i}") #imprime cada elemento

elements = [] #cria a lista elements

for i in range(0, 6): #vai considerar 6 elementos, contando em números a partir do zero
  print(f"Adding {i} to the list.") #imprime que adicionou os elementos à lista elements

  elements.append(i) #essa liha é para de fato adicionar esses 5 elementos à lista element (notar tabulação dentro do for)

for i in elements: #busca o item dentro da lista elements
  print(f"Element was: {i}") #imprime o item
# Out:
# This is count 1
# This is count 2
# This is count 3
# This is count 4
# This is count 5
# A fruit of type: apples
# A fruit of type: oranges
# A fruit of type: pears
# A fruit of type: apricots
# I got 1
# I got pennies
# I got 2
# I got dimes
# I got 3
# I got quarters
# Adding 0 to the list.
# Adding 1 to the list.
# Adding 2 to the list.
# Adding 3 to the list.
# Adding 4 to the list.
# Adding 5 to the list.
# Element was: 0
# Element was: 1
# Element was: 2
# Element was: 3
# Element was: 4
# Element was: 5

# %% [markdown]
# ### Novidades neste exercício
#
#
#
# *   Uso prático das listas
# *   Criação das listas
# *   Adicionar elementos às listas
# *   Uso do For para trabalhar com as listas inteiras

# %% [markdown]
# ### Erros que cometi neste exercício
#
# Esqueci de dar espaço antes de puxar o elemento da lista na linha 12 e ficou feio.

# %% [markdown]
# ## EXERCÍCIO 17 - Loops While

# %%
i = 0 #deu o valor inicial do elemento (i) ##os comentários são inseridos apenas lendo o teste, sem rodar, e alterados se necessário depois do teste.
numbers = [] #criou a lista numbers

while i < 6: #criou um laço que vai atuar enquanto o (i) for menor que 6
  print(f"This is cycle #{i + 1}") #acrescentei essa linha pra usar o i como noção das repetições do loop
  print(f"At the top i is {i}") #deve imprimir que o valor do i conforme o loop é executado
  numbers.append(i) #acrescenta esse valor de i à lista numbers

  i = i + 1 #soma 1 ao valor do i que o código acabou de usar no loop
  print("Number now: ", numbers) #ele vai imprimir a lista inteira disponível na etapa do ciclo while
  print(f"At the bottom i is {i}") #deve imprimir o valor mais recente de i após a soma

print("The numbers: ") #só imprime a frase
for num in numbers: #vai chamar cada elemento (num) da lista numbers
  print(num) #imprime cada um desses elementos)
# Out:
# This is cycle #1
# At the top i is 0
# Number now:  [0]
# At the bottom i is 1
# This is cycle #2
# At the top i is 1
# Number now:  [0, 1]
# At the bottom i is 2
# This is cycle #3
# At the top i is 2
# Number now:  [0, 1, 2]
# At the bottom i is 3
# This is cycle #4
# At the top i is 3
# Number now:  [0, 1, 2, 3]
# At the bottom i is 4
# This is cycle #5
# At the top i is 4
# Number now:  [0, 1, 2, 3, 4]
# At the bottom i is 5
# This is cycle #6
# At the top i is 5
# Number now:  [0, 1, 2, 3, 4, 5]
# At the bottom i is 6
# The numbers:
# 0
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# ### Novidades neste exercício
#
# * Uso do while para criar a lista com uma quantidade especificada de elementos
# * Imprime os valores acrescentados conforme o ciclo roda
# * Acrescentei a linha usando o valor do i como referência para entender melhor o funcionamento dos ciclos conforme o código avança

# %% [markdown]
# ### Erros que cometi neste exercício

# %% [markdown]
# ## EXERCÍCIO 18 - Nomes, variáveis, códigos, funções

# %%
def print_two(*args): #criou o método print_two; o asterisco é para ele puxar os argumentos conforme explicados na linha 2
  arg1, arg2 = args #disse pro código que 'arg1' e 'arg2' são os argumentos desse método, sem precisar já escrever no parêntesis
  print(f"arg1: {arg1}, arg2: {arg2}") #vai imprimir os argumentos conforme adicionados ao chamar o método

def print_two_again(arg1, arg2): #criou o método print_two_again
  print(f"arg1: {arg1}, arg2: {arg2}") #se entregar argumentos diferentes para esse método, ele não vai alterar os argumentos do método print_two

def print_one(arg1): #criou o método print_one
  print(f"arg1: {arg1}") #vai imprimir o argumento disponível para o print_one

def print_none(): #definiu o método print_none, que não pede argumentos
  print("I got nothyin'.") #imprime

print_two("Zed", "Shaw") #chama o método, definindo os argumentos
print_two_again("Bibi", "Frufru")#chama o método, definindo os argumentos - alterado do código original para teste
print_one("First!")#chama o método, definindo os argumentos
print_none()#chama o método, definindo os argumentos
# Out:
# arg1: Zed, arg2: Shaw
# arg1: Bibi, arg2: Frufru
# arg1: First!
# I got nothyin'.

# %% [markdown]
# ### Novidades neste exercício
#
#
#
# *   Prática da criação simples dos métodos
# *   Uso dos métodos de forma simplificada
# * E se eu quisesse que os argumentos dos meus métodos fossem puxados de uma lista....?

# %% [markdown]
# ### Erros que cometi neste exercício
#
# Eu arrasei, mereço um 10
# (espero que esse material não fique público)

# %% [markdown]
# ## EXERCÍCIO 19 - Funções e variáveis

# %%
def cheese_and_crackers(cheese_count, boxes_of_crackers): #criou a função com 2 argumentos
    print(f"You have {cheese_count} cheeses!") #imprime arg1
    print(f"You have {boxes_of_crackers} boxes of crackers!") #imprime arg2
    print("Man that's enough for a party!") #imprime
    print("Get a blanket.\n") #imprime


print("We can just give the function numbers directly:") #imprime
cheese_and_crackers(20, 30) #chama a função diretamente com os valores


print("OR, we can use variables from our script:") #imprime e mostra como usar a função com combinação de variáveis
amount_of_cheese = 10 #deu o valor 1
amount_of_crackers = 50 #deu o valor 2

cheese_and_crackers(amount_of_cheese, amount_of_crackers) #chamou o método atribuindo as variáveis aos argumentos


print("We can even do math inside too:") #imprime mostrando como usar soma para o valor dos atributos
cheese_and_crackers(10 + 20, 5 + 6) #mostra que se pode escrever a soma, separa os argumentos por VÍRGULA


print("And we can combine the two, variables and math:") #imprime e mostra a combinação de possibilidades
cheese_and_crackers(amount_of_cheese + 100, amount_of_crackers + 1000) #definiu os argumentos de forma mista
# Out:
# We can just give the function numbers directly:
# You have 20 cheeses!
# You have 30 boxes of crackers!
# Man that's enough for a party!
# Get a blanket.
#
# OR, we can use variables from our script:
# You have 10 cheeses!
# You have 50 boxes of crackers!
# Man that's enough for a party!
# Get a blanket.
#
# We can even do math inside too:
# You have 30 cheeses!
# You have 11 boxes of crackers!
# Man that's enough for a party!
# Get a blanket.
#
# And we can combine the two, variables and math:
# You have 110 cheeses!
# You have 1050 boxes of crackers!
# Man that's enough for a party!
# Get a blanket.

# %% [markdown]
# ### Novidades neste exercício
#
# * Criou funções/ métodos com strings
# * Realizou operações com variáveis e números dentro das funções/ métodos

# %% [markdown]
# ### Erros que cometi neste exercício

# %% [markdown]
# ## EXERCÍCIO 20

# %%
def add(a, b): #criou a função com a operação
  print(f"ADDING {a} + {b}") #imprime que está somando
  return a + b #salva o valor

def subtract(a, b): #criou a função subtract
  print(f"SUBTRACTING {a} - {b}") #vai imprimir a subtração de a - b
  return a - b #salva o valor

def multiply(a, b): #criou a função com a operação
  print(f"MULTIPLYING {a} * {b}") #imprime que está somando
  return a * b #salva o valor

def divide(a, b):#criou a função com a operação
  print(f"DIVIDING {a} / {b}") #imprime que está somando
  return a / b  #salva o valor

print("Let's do some more math with just functions!") #só imprime

age = add(30, 5) #puxa o método com os valores definidos para aplicar
height = subtract(78, 4) #puxa o método com os valores definidos para aplicar
weight = multiply(90, 2) #puxa o método com os valores definidos para aplicar
iq = divide(100, 2) #puxa o método com os valores definidos para aplicar

print(f"Age: {age}, height: {height}, weight: {weight}, IQ: {iq}") #vai puxar as respostas todas salvas

#Charada extra:
print("Here is a puzzle.") #só mprime
what = add(age, subtract(height, multiply(weight, divide(iq, 2))))
#iq = 50; add(age, subtract(height, multiply(weight, divide(50, 2))))
#divide(50, 2) = 25; add(age, subtract(height, multiply(weight, 25)))
#multiply(weight, 25) // weight = 90*2 = 180 // multiply(180, 25) = 4500 // add(age, subtract(height, 4500))
#subtract(height, 4500) = 74-4500 = 4426 // add(age, 4426)
#add(35, 4426) = 4461 UÉ???
print("That becomes: ", what, "Can you do it by hand?")
# Out:
# Let's do some more math with just functions!
# ADDING 30 + 5
# SUBTRACTING 78 - 4
# MULTIPLYING 90 * 2
# DIVIDING 100 / 2
# Age: 35, height: 74, weight: 180, IQ: 50.0
# Here is a puzzle.
# DIVIDING 50.0 / 2
# MULTIPLYING 180 * 25.0
# SUBTRACTING 74 - 4500.0
# ADDING 35 + -4426.0
# That becomes:  -4391.0
# Can you do it by hand?

# %% [markdown]
# ### Novidades neste exercício
#
# * Criou várias funções/ métodos com operações
# * Relacionou valores às variáveis para aplicar aos métodos
# * Aplicou funções dentro de funções

# %% [markdown]
# ### Erros que cometi neste exercício
#
# A charada extra :(
